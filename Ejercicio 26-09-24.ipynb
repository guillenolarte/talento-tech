# %% [markdown]
# Creación de Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

value_n_list = ['Gerardo', 'Éduardo', 'Stella', 'Monica', 'Juan', 'Ésteban', 'Gina', 'Àlex', 'Fany', 'Andrea'] # Changed - to = to assign the list to the variable
print(value_n_list)

value_a_list = [18, 25, 35, 28, 22, 21, 41, 29, 30, 27 ]
value_w_list = [66, 75, 58, 61.4, 80, 99, 78.2, 85, 57, 74.5 ]
value_h_list = [1.58, 1.82, 1.62, 1.51, 1.62, 1.72, 1.58, 1.62, 1.65, 1.55 ]

Data_dict = {'Name': value_n_list, 'Age': value_a_list, 'Weight': value_w_list, 'Height': value_h_list}
print(Data_dict)

df = pd.DataFrame(Data_dict)

df
# Out:
# ['Gerardo', 'Éduardo', 'Stella', 'Monica', 'Juan', 'Ésteban', 'Gina', 'Àlex', 'Fany', 'Andrea']
# {'Name': ['Gerardo', 'Éduardo', 'Stella', 'Monica', 'Juan', 'Ésteban', 'Gina', 'Àlex', 'Fany', 'Andrea'], 'Age': [18, 25, 35, 28, 22, 21, 41, 29, 30, 27], 'Weight': [66, 75, 58, 61.4, 80, 99, 78.2, 85, 57, 74.5], 'Height': [1.58, 1.82, 1.62, 1.51, 1.62, 1.72, 1.58, 1.62, 1.65, 1.55]}
#       Name  Age  Weight  Height
# 0  Gerardo   18    66.0    1.58
# 1  Éduardo   25    75.0    1.82
# 2   Stella   35    58.0    1.62
# 3   Monica   28    61.4    1.51
# 4     Juan   22    80.0    1.62
# 5  Ésteban   21    99.0    1.72
# 6     Gina   41    78.2    1.58
# 7     Àlex   29    85.0    1.62
# 8     Fany   30    57.0    1.65
# 9   Andrea   27    74.5    1.55

# %%
df['Bmi'] = df['Weight'] / (df['Height'] ** 2)
df
# Out:
#       Name  Age  Weight  Height        bmi        Bmi
# 0  Gerardo   18    66.0    1.58  26.438071  26.438071
# 1  Éduardo   25    75.0    1.82  22.642193  22.642193
# 2   Stella   35    58.0    1.62  22.100290  22.100290
# 3   Monica   28    61.4    1.51  26.928643  26.928643
# 4     Juan   22    80.0    1.62  30.483158  30.483158
# 5  Ésteban   21    99.0    1.72  33.464035  33.464035
# 6     Gina   41    78.2    1.58  31.325108  31.325108
# 7     Àlex   29    85.0    1.62  32.388355  32.388355
# 8     Fany   30    57.0    1.65  20.936639  20.936639
# 9   Andrea   27    74.5    1.55  31.009365  31.009365

# %%
df.describe()
# Out:
#              Age     Weight     Height        bmi        Bmi
# count  10.000000  10.000000  10.000000  10.000000  10.000000
# mean   27.600000  73.410000   1.627000  27.771586  27.771586
# std     6.801961  13.187406   0.088575   4.617136   4.617136
# min    18.000000  57.000000   1.510000  20.936639  20.936639
# 25%    22.750000  62.550000   1.580000  23.591162  23.591162
# 50%    27.500000  74.750000   1.620000  28.705901  28.705901
# 75%    29.750000  79.550000   1.642500  31.246172  31.246172
# max    41.000000  99.000000   1.820000  33.464035  33.464035
