# %% [markdown]
# **Ejercicio PDF 1**

# %%
from tensorflow import keras
# The following line is causing the error, because you're using TensorFlow's Keras
# from keras.preprocessing.text import Tokenizer
# Instead, use the following line:
from tensorflow.keras.preprocessing.text import Tokenizer
# This line is already correct and importing the same functionality
# from tensorflow.keras.preprocessing.text import Tokenizer

# %%
# frases relacionadas con hola mundo
frases = [
    'Hola mundo'
    'Hola a todos'
    'Hola a todo el mundo'
]

# Genera el diccionario de tokens
tokenizer = keras.preprocessing.text.Tokenizer(num_words=10)
tokenizer.fit_on_texts(frases)
tokenizer.word_index
print(tokenizer.word_index)
# Out:
# {'a': 1, 'hola': 2, 'mundohola': 3, 'todoshola': 4, 'todo': 5, 'el': 6, 'mundo': 7}

# %%
# Generacion de secuencia de tokenizacdas
sequences = tokenizer.texts_to_sequences(frases)
print(sequences)
# Out:
# [[2, 3, 1, 4, 1, 5, 6, 7]]

# %%
# Rellana las secuencias a una longitud uniforme
padded = keras.preprocessing.sequence.pad_sequences(sequences)
print(padded)
# Out:
# [[2 3 1 4 1 5 6 7]]

# %%
# frases relacionadas con hola mundo
frases = [
    'Hola mundo'
    'Hola a todos'
    'Hola a todo el mundo'
    'Buen dia, como estas hoy'
    ]

    # Genera el diccionario de tokens
tokenizer = keras.preprocessing.text.Tokenizer(num_words=20)
tokenizer.fit_on_texts(frases)
tokenizer.word_index
print(tokenizer.word_index)

# Generacion de secuencia de tokenizacdas
sequences = tokenizer.texts_to_sequences(frases)
print(sequences)

# Rellana las secuencias a una longitud uniforme
padded = keras.preprocessing.sequence.pad_sequences(sequences)
print(padded)
# Out:
# {'a': 1, 'hola': 2, 'mundohola': 3, 'todoshola': 4, 'todo': 5, 'el': 6, 'mundobuen': 7, 'dia': 8, 'como': 9, 'estas': 10, 'hoy': 11}
# [[2, 3, 1, 4, 1, 5, 6, 7, 8, 9, 10, 11]]
# [[ 2  3  1  4  1  5  6  7  8  9 10 11]]

# %%
# frases relacionadas con hola mundo
frases = [
    'Hola mundo'
    'Hola a todos'
    'Hola a todo el mundo'
    'Buen dia, como estas hoy'
    ]

    # Genera el diccionario de tokens
tokenizer = keras.preprocessing.text.Tokenizer(num_words=20,
                                               oov_token="<OOV>")
tokenizer.fit_on_texts(frases)
tokenizer.word_index
print(tokenizer.word_index)

# Generacion de secuencia de tokenizacdas
sequences = tokenizer.texts_to_sequences(frases)
print(sequences)

# Rellana las secuencias a una longitud uniforme
padded = keras.preprocessing.sequence.pad_sequences(sequences)
print(padded)
# Out:
# {'<OOV>': 1, 'a': 2, 'hola': 3, 'mundohola': 4, 'todoshola': 5, 'todo': 6, 'el': 7, 'mundobuen': 8, 'dia': 9, 'como': 10, 'estas': 11, 'hoy': 12}
# [[3, 4, 2, 5, 2, 6, 7, 8, 9, 10, 11, 12]]
# [[ 3  4  2  5  2  6  7  8  9 10 11 12]]

# %%
# frases relacionadas con hola mundo
frases = [
    'Hola mundo'
    'Hola a todos'
    'Hola a todo el mundo'
    'Buen dia, como estas hoy'
    ]

    # Genera el diccionario de tokens
tokenizer = keras.preprocessing.text.Tokenizer(num_words=20,
                                               oov_token="<OOV>")
tokenizer.fit_on_texts(frases)
tokenizer.word_index
print(tokenizer.word_index)

# Generacion de secuencia de tokenizacdas
sequences = tokenizer.texts_to_sequences(frases)
print(sequences)

# Rellana las secuencias a una longitud uniforme
padded = keras.preprocessing.sequence.pad_sequences(sequences,
                                                    padding = 'post',
                                                    truncating = 'post')
# frases relacionadas con hola mundo
frases = [
    'Hola mundo',
    'Hola a todos',
    'Hola a todo el mundo',
    'Buen dia, como estas hoy'
    ]

    # Genera el diccionario de tokens
from tensorflow import keras
tokenizer = keras.preprocessing.text.Tokenizer(num_words=20,
                                               oov_token="<OOV>")
tokenizer.fit_on_texts(frases)
tokenizer.word_index
print(tokenizer.word_index)

# Generacion de secuencia de tokenizacdas
sequences = tokenizer.texts_to_sequences(frases)
print(sequences)

# Rellana las secuencias a una longitud uniforme
padded = keras.preprocessing.sequence.pad_sequences(sequences,
                                                    padding = 'post',
                                                    truncating = 'post')
print('relleno con post')
print(padded)
print('truncado con post')
# Out:
# {'<OOV>': 1, 'a': 2, 'hola': 3, 'mundohola': 4, 'todoshola': 5, 'todo': 6, 'el': 7, 'mundobuen': 8, 'dia': 9, 'como': 10, 'estas': 11, 'hoy': 12}
# [[3, 4, 2, 5, 2, 6, 7, 8, 9, 10, 11, 12]]
# {'<OOV>': 1, 'hola': 2, 'mundo': 3, 'a': 4, 'todos': 5, 'todo': 6, 'el': 7, 'buen': 8, 'dia': 9, 'como': 10, 'estas': 11, 'hoy': 12}
# [[2, 3], [2, 4, 5], [2, 4, 6, 7, 3], [8, 9, 10, 11, 12]]
# relleno con post
# [[ 2  3  0  0  0]
#  [ 2  4  5  0  0]
#  [ 2  4  6  7  3]
#  [ 8  9 10 11 12]]
# truncado con post

# %% [markdown]
# **Ejercicio pdf 2**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Importar dataset, handling bad lines
df = pd.read_csv('/content/IMDB-Dataset.csv', on_bad_lines='skip')
# or 'warn' to get info about skipped lines

df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
# checking dataset description
df.describe()
# Out:
#                                                    review sentiment
# count                                               50000     50000
# unique                                              49582         2
# top     Loved today's show!!! It was a variety and not...  positive
# freq                                                    5     25000

# %%
#sentiment count
df['sentiment'].value_counts()
# Out:
# sentiment
# positive    25000
# negative    25000
# Name: count, dtype: int64

# %%
review = []
# Replacing 'IMDB' with 'df' to access the DataFrame
sentences = list(df['review'])
for sen in sentences:
  review.append(sen)

# %%
labels = df['sentiment']
labels = np.array(list(map(lambda x: 1 if x=="positive" else 0, labels)))

# %%
from sklearn.model_selection import train_test_split
train_sentences, test_sentences, train_labels, test_labels = train_test_split(review, labels, test_size=0.2)

# %%
# parametros
vocab_size = 10000
embedding_dim = 16
max_length = 120
trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"

# %%
# !pip install tensorflow
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import warnings
warnings.filterwarnings('ignore')

# initilialize the tokenizer class
tokenizer = Tokenizer(num_words = vocab_size, char_level=False, oov_token=oov_tok)
tokenizer.fit_on_texts(train_sentences)

# generate the word index dictionary for the training  sentences
tokenizer.fit_on_texts(train_sentences)
word_index = tokenizer.word_index

# Generate and pad training sequences
training_sequences = tokenizer.texts_to_sequences(train_sentences)
training_padded = pad_sequences(training_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

# Generate and pad the test sequences
testing_sequences = tokenizer.texts_to_sequences(test_sentences)
testing_padded = pad_sequences(testing_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

# %%
# ... (your code)

# build the model
model = keras.Sequential([
    keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    keras.layers.Flatten(),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

# Build the model explicitly
model.build(input_shape=(None, max_length))  # Replace 'None' with batch size if known

# setup the training parameters
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

print(model.summary())
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_8 (Embedding)              │ (None, 120, 16)             │         160,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_6 (Flatten)                  │ (None, 1920)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 64)                  │         122,944 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_15 (Dense)                     │ (None, 1)                   │              65 │
# ...

# %%
# train the model
num_epochs = 10
history = model.fit(training_padded,
                    train_labels,
                    epochs=num_epochs,
                    validation_data=(testing_padded, test_labels))
# Out:
# Epoch 1/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 126s 101ms/step - accuracy: 0.9407 - loss: 0.1716 - val_accuracy: 0.8399 - val_loss: 0.4401
# Epoch 2/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 146s 104ms/step - accuracy: 0.9557 - loss: 0.1397 - val_accuracy: 0.8396 - val_loss: 0.4422
# Epoch 3/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 126s 101ms/step - accuracy: 0.9628 - loss: 0.1215 - val_accuracy: 0.8385 - val_loss: 0.4807
# Epoch 4/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 143s 102ms/step - accuracy: 0.9674 - loss: 0.1116 - val_accuracy: 0.8369 - val_loss: 0.5197
# Epoch 5/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 140s 101ms/step - accuracy: 0.9730 - loss: 0.0974 - val_accuracy: 0.8342 - val_loss: 0.5433
# Epoch 6/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 142s 101ms/step - accuracy: 0.9785 - loss: 0.0841 - val_accuracy: 0.8357 - val_loss: 0.5904
# Epoch 7/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 145s 104ms/step - accuracy: 0.9803 - loss: 0.0760 - val_accuracy: 0.8323 - val_loss: 0.6155
# Epoch 8/10
# ...

# %%
# Graficar historial de entrenamiento
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

# %%
# Realizar predicciones en el conjunto de prueba
y_pred = model.predict(testing_padded)

# generar metricas, recall, precision, R2
print(classification_report(test_labels, y_pred.round()))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 34ms/step
#               precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83      5032
#            1       0.83      0.83      0.83      4968
#
#     accuracy                           0.83     10000
#    macro avg       0.83      0.83      0.83     10000
# weighted avg       0.83      0.83      0.83     10000

# %%
# generar matriz de confusion
cm = confusion_matrix(test_labels, y_pred.round())
print(cm)

# Grafico matriz de confusion
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Negative', 'Positive'], yticklabels=['Negative', 'Positive'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# [[4258  774]
#  [1190 3778]]

# %% [markdown]
# Ejercicio pdf 3

# %%
# build the model
model = keras.Sequential([
    keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    keras.layers.LSTM(64, return_sequences=True),
    keras.layers.LSTM(32),
    keras.layers.LSTM(16),
    keras.layers.Dense(6, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')

    #colocar dropout de 0.25 despues de cada LSTM y de la primera dense
])

#--------------
# Al final deben agregar las métricas completas de clasificación:
# matriz de confusión, reporte de clasificación, curva ROC (AUC),  e histograma de errores
#--------------


# Build the model explicitly
model.build(input_shape=(None, max_length))  # Replace 'None' with batch size if known

# setup the training parameters
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

print(model.summary())
# Out:
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_10 (Embedding)             │ (None, 120, 16)             │         160,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_3 (LSTM)                        │ (None, 120, 64)             │          20,736 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_4 (LSTM)                        │ (None, 32)                  │          12,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_18 (Dense)                     │ (None, 6)                   │             198 │
# ...

# %%
# train the model
num_epochs = 10
history = model.fit(training_padded,
                    train_labels,
                    epochs=num_epochs,
                    validation_data=(testing_padded, test_labels))
# Out:
# Epoch 1/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 127s 98ms/step - accuracy: 0.5724 - loss: 0.6623 - val_accuracy: 0.6758 - val_loss: 0.6093
# Epoch 2/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 123s 98ms/step - accuracy: 0.6812 - loss: 0.6038 - val_accuracy: 0.7540 - val_loss: 0.5911
# Epoch 3/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 140s 112ms/step - accuracy: 0.7591 - loss: 0.5526 - val_accuracy: 0.8024 - val_loss: 0.4457
# Epoch 4/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 124s 99ms/step - accuracy: 0.8320 - loss: 0.4003 - val_accuracy: 0.8283 - val_loss: 0.3971
# Epoch 5/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 125s 100ms/step - accuracy: 0.8421 - loss: 0.3690 - val_accuracy: 0.8393 - val_loss: 0.3642
# Epoch 6/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 142s 100ms/step - accuracy: 0.8875 - loss: 0.2855 - val_accuracy: 0.8381 - val_loss: 0.3743
# Epoch 7/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 144s 102ms/step - accuracy: 0.8714 - loss: 0.3124 - val_accuracy: 0.8255 - val_loss: 0.3920
# Epoch 8/10
# ...

# %%
# Graficar el historial de entrenamiento
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

# %%
# Realizar predicciones en el conjunto de prueba
y_pred = model.predict(testing_padded)

# generar metricas, recall, precision, R2
print(classification_report(test_labels, y_pred.round()))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 34ms/step
#               precision    recall  f1-score   support
#
#            0       0.81      0.88      0.85      5032
#            1       0.87      0.80      0.83      4968
#
#     accuracy                           0.84     10000
#    macro avg       0.84      0.84      0.84     10000
# weighted avg       0.84      0.84      0.84     10000

# %%
# generar matriz de confusion
cm = confusion_matrix(test_labels, y_pred.round())
print(cm)

# Grafico matriz de confusion
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Negative', 'Positive'], yticklabels=['Negative', 'Positive'])
plt.xlabel('Predicted')
plt
# Out:
# [[4439  593]
#  [1010 3958]]
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py'>

# %%
from google.colab import files

# Guardar notebook como HTML
# !jupyter nbconvert --to html /content/Ejercicio_clase_de_NLP.ipynb

# Descargar el archivo HTML
files.download('Ejercicio_clase_de_NLP.html')
# Out:
# [NbConvertApp] Converting notebook /content/Ejercicio_clase_de_NLP.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 4 image(s).
# [NbConvertApp] Writing 513034 bytes to /content/Ejercicio_clase_de_NLP.html
